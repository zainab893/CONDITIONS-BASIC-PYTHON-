# %%
# SYEDA ZAINAB FATIMA
# WS25-PAK-INP-AI-01

# %%
# TOPIC
# CONDITIONS

# %%
# IF CONDITION

# EXAMPLE 1
num = 22
if num > 20:
  print("The number is greater than 20")

# EXAMPLE 2
age = 19
if age >= 18:
  print("You are eligible to have driving license")

# EXAMPLE 3
num = 20
if num / 2:
  print("The number is even")

# EXAMPLE 4
num = 6**2
if num == 36:
  print("The number is correct")

# EXAMPLE 5
num = 50 % 10
if num == 0:
  print("the number is divisible by 10")

# EXAMPLE 6
Age = 25
if Age >= 18:
  print("You are eligible to vote")

# EXAMPLE 7
num = 65
if num >=60:
  print("your retirement time is here")

# EXAMPLE 8
marks = 95
if marks >= 90:
  print("Excellent!")

# EXAMPLE 9
percentage = 85
if percentage <= 80:
  print("you could work hard")

# EXAMPLE 10
num = int(input("Enter a number: "))
if num % 6 == 1:
  print("that number is not divisible by 6 ")
# Out:
# The number is greater than 20
# You are eligible to have driving license
# The number is even
# The number is correct
# the number is divisible by 10
# You are eligible to vote
# your retirement time is here
# Excellent!
# Enter a number: 19
# that number is not divisible by 6

# %%
# ELIF CONDITION

# EXAMPLE 1
number = 18
if number == 18:
  print("You are eligible to have driving license")
elif number < 18:
  print("You are not eligible to have  driving license")

# EXAMPLE 2
password = input("Enter special characters like @$#")
if password == "@$#":
  print("Correct!")
elif password != "special characters like @$#":
  print("Please enter a valid password")

# EXAMPLE 3
Email = input("Enter your email: ")
if Email == "syedazainabf405@gmail.com":
  print("correct!")
elif Email != "syedazainabf405@gmail.com":
  print("Please enter a valid email")

# EXAMPLE 4
marks = int(input("enter your marks"))
if marks >= 60:
  print("you have passed")
elif marks < 60:
  print("fail")

# EXAMPLE 5
age = int(input("Enter your age: "))
if age >= 60:
  print("you have retired")
elif age == 59:
  print("you are not ready for retirement")
elif age < 59:
  print("you are too young for retirement")

# EXAMPLE 6
Final_defence_marks = float(input("Enter your final defence marks: "))
if Final_defence_marks >= 80:
  print("OUTSTANDING!")
elif Final_defence_marks >=70:
  print("GOOD")
elif Final_defence_marks >= 60:
  print("AVERAGE")

# EXAMPLE 7
AIC_Evaluation = float(input("enter the number: "))
if AIC_Evaluation >=90:
  print("EXCELLENT")
elif AIC_Evaluation >=80:
  print("GOOD")
elif AIC_Evaluation >=70:
  print("OK")
elif AIC_Evaluation >=60:
  print("WORK HARD")

# EXAMPLE 8
radiation_exposure_space = 500
if radiation_exposure_space > 500:
  print("extreme and unsafe radiation exposure")
elif radiation_exposure_space > 50:
  print("Moderate radiation exposure")
elif radiation_exposure_space < 50:
  print("safe radiation level")

# EXAMPLE 9
temperature_space = int(input("enter the temperature:"))
if temperature_space < -150:
  print("extreme cold")
elif temperature_space > 100:
  print("very hot")

# EXAMPLE 10
gravity = -1
if gravity < 1:
    print("Low gravity, probably in space.")
elif gravity > 1:
    print("High gravity, probably on Earth.")
# Out:
# You are eligible to have driving license
# Enter special characters like @$#@
# Please enter a valid password
# Enter your email: syedazainabf405@gamil.com
# Please enter a valid email
# enter your marks61
# you have passed
# Enter your age: 22
# you are too young for retirement
# Enter your final defence marks: 88.5
# OUTSTANDING!
# enter the number: 88.8
# GOOD
# Moderate radiation exposure
# enter the temperature:-160
# extreme cold
# Low gravity, probably in space.

# %%
# IF ELSE CONDITION

# EXAMPLE 1
Age = int(input("enter your age"))
if Age >= 18:
  print("You are eligible to vote")
else:
  print("you are not eligible to vote")


# EXAMPLE 2
grad_years = 4
if grad_years > 4:
  print("you have spend extra years")
elif grad_years < 4:
  print("you have not completed your 4 years of graduation")
else:
  print("Congratulations, you have successfully completed your degree")

# EXAMPLE 3
no_of_students = 80
if no_of_students > 80:
  print("Too much students for trip")
elif no_of_students < 80:
  print("very less students for trip, we cannot go")
else:
  print("we can go for trip")

# EXAMPLE 4
marks = int(input("enter your marks: "))
if marks >= 80:
  print("very good")
elif marks >=70:
  print("good")
else:
  print("ok")

# EXAMPLE 5
Final_defence_marks = float(input("Enter your final defence marks: "))
if Final_defence_marks >= 80:
  print("OUTSTANDING!")
elif Final_defence_marks >=70:
  print("GOOD")
else:
  print("AVERAGE")

# EXAMPLE 6
pressure = 0
if pressure == 0:
    print("This is space.")
elif pressure < 1:
    print("Very low pressure.")
else:
    print("Normal pressure")

# EXAMPLE 7
distance = 1100000
if distance > 1000000:
    print("Very far, deep in space.")
elif distance < 100000:
    print("Far from Earth, likely in space.")
else:
    print("Close to Earth.")

# EXAMPLE 8
gravity = -1
if gravity == 0:
    print("In space.")
elif gravity < 1:
    print("Near space.")
else:
    print("On Earth.")

# EXAMPLE 9
age = 20
if age >= 20:
  print("you can go to the concert")
elif age < 20:
  print("you cannot go to the concert")

else:
  ("you are a kid")

# EXAMPLE 10
num = 45
if num == 40/2:
  print("the number is even")
else:
  print("the number is odd")
# Out:
# enter your age17
# you are not eligible to vote
# Congratulations, you have successfully completed your degree
# we can go for trip
# enter your marks: 81
# very good
# Enter your final defence marks: 88.5
# OUTSTANDING!
# This is space.
# Very far, deep in space.
# Near space.
# you can go to the concert
# the number is odd
